# %% [markdown]
# # Pull BLS Table B-1a employment data
#
# The pull logic lives in `pull_data.py` so the same code runs from the notebook, the
# CLI, and `../update_monthly.sh`. Running it snapshots the current
# `b1a_wide_seriesid.csv` to `b1a_wide_seriesid_pre_revision_<YYYY_MM>.csv` — the
# vintage whose last month is still preliminary, which drives the homepage
# preliminary-vs-revised columns — and then overwrites `b1a_wide_seriesid.csv` with
# the fresh BLS pull. An existing snapshot is never overwritten, so re-running is safe.

# %%
# %run pull_data.py
